# %%
  import tensorflow as tf

# %%
train_dir = "/kaggle/input/dataset/dataset/train"
test_dir = "/kaggle/input/dataset/dataset/test"

# %%
IMG_SIZE = (124, 124)
BATCH_SIZE = 32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True
)
# Out:
# Found 6675 files belonging to 8 classes.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 1794 files belonging to 8 classes.

# %%
class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)
# Out:
# Classes: ['Textile_waste', 'construction_demolition_waste', 'hazardous_waste', 'kitchen_waste', 'medical', 'organic_waste', 'recycled_waste', 'sanitary_waste']

# %%
import os
from PIL import Image

dataset_path = train_dir  # Update with your dataset path

for folder in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, folder)
    if os.path.isdir(folder_path):
        for file in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file)
            try:
                with Image.open(file_path) as img:
                    img_format = img.format
                    print(f"File: {file} | Format: {img_format}")  # Print format of all images
                    
                    if img_format.lower() != "png":
                        print(f"❌ Non-PNG Image: {file_path} | Detected Format: {img_format}")
            except Exception as e:
                print(f"⚠️ Error reading {file_path}: {e}")  # Handle corrupt files
# Out:
# File: tetra_pak 76.png | Format: PNG
# File: beverage_cans 35.png | Format: PNG
# File: construction_scrap 67.png | Format: PNG
# File: paper 501.png | Format: PNG
# File: paper_cups 64.png | Format: PNG
# File: construction_scrap 23.png | Format: PNG
# File: plastic_bottle 23.png | Format: PNG
# File: glass 66.png | Format: PNG
# File: plastic_bag 115.png | Format: PNG
# File: cardboard 76.png | Format: PNG
# File: beverage_cans 11.png | Format: PNG
# File: metal_objects 23.png | Format: PNG
# File: glass 32.png | Format: PNG
# File: beverage_cans 125.png | Format: PNG
# File: construction_scrap 14.png | Format: PNG
# File: paper 56.png | Format: PNG
# File: beverage_cans 63.png | Format: PNG
# File: spray_cans 47.png | Format: PNG
# File: tetra_pak 12.png | Format: PNG
# File: cardboard 22.png | Format: PNG
# File: glass 22.png | Format: PNG
# File: plastic_bottle 98.png | Format: PNG
# File: paper 14.png | Format: PNG
# File: plastic_bag 134.png | Format: PNG
# File: construction_scrap 58.png | Format: PNG
# File: plastic_bottle 10.png | Format: PNG
# File: metal_objects 22.png | Format: PNG
# File: spray_cans 115.png | Format: PNG
# File: tetra_pak 37.png | Format: PNG
# File: construction_scrap 13.png | Format: PNG
# File: metal_objects 15.png | Format: PNG
# File: plastic_bottle 21.png | Format: PNG
# File: plastic_bottle 75.png | Format: PNG
# File: glass 73.png | Format: PNG
# File: metal_objects 2.png | Format: PNG
# File: plastic_containers 130.png | Format: PNG
# File: spray_cans 40.png | Format: PNG
# File: spray_cans 16.png | Format: PNG
# File: glass 43.png | Format: PNG
# File: plastic_bag 19.png | Format: PNG
# File: plastic_bag 82.png | Format: PNG
# File: construction_scrap 74.png | Format: PNG
# File: paper 100.png | Format: PNG
# File: plastic_containers 85.png | Format: PNG
# File: plastic_containers 176.png | Format: PNG
# File: plastic_containers 79.png | Format: PNG
# File: paper_cups 4.png | Format: PNG
# File: paper 131.png | Format: PNG
# File: glass 49.png | Format: PNG
# File: glass 126.png | Format: PNG
# File: news_paper 29.png | Format: PNG
# File: plastic_containers 68.png | Format: PNG
# File: paper_cups 32.png | Format: PNG
# File: plastic_bottle 56.png | Format: PNG
# File: plastic_bag 14.png | Format: PNG
# File: paper_cups 73.png | Format: PNG
# File: news_paper 32.png | Format: PNG
# File: glass 133.png | Format: PNG
# File: metal_containers 52.png | Format: PNG
# File: paper 101.png | Format: PNG
# File: plastic_bottle 101.png | Format: PNG
# File: beverage_cans 13.png | Format: PNG
# File: spray_cans 13.png | Format: PNG
# File: cardboard 37.png | Format: PNG
# File: cardboard 119.png | Format: PNG
# File: metal_containers 91.png | Format: PNG
# File: beverage_cans 36.png | Format: PNG
# File: news_paper 81.png | Format: PNG
# File: glass 55.png | Format: PNG
# File: plastic_bottle 57.png | Format: PNG
# File: paper_cups 49.png | Format: PNG
# File: paper 115.png | Format: PNG
# File: plastic_containers 91.png | Format: PNG
# File: paper_cups 2.png | Format: PNG
# File: spray_cans 23.png | Format: PNG
# File: plastic_bottle 133.png | Format: PNG
# File: glass 1.png | Format: PNG
# File: beverage_cans 19.png | Format: PNG
# File: cardboard 120.png | Format: PNG
# File: plastic_bag 11.png | Format: PNG
# File: cardboard 488.png | Format: PNG
# File: plastic_containers 178.png | Format: PNG
# File: plastic_containers 132.png | Format: PNG
# File: plastic_bottle 100.png | Format: PNG
# File: paper_cups 79.png | Format: PNG
# File: metal_containers 17.png | Format: PNG
# File: plastic_containers 75.png | Format: PNG
# File: paper 136.png | Format: PNG
# File: glass 88.png | Format: PNG
# File: spray_cans 37.png | Format: PNG
# File: plastic_bottle 143.png | Format: PNG
# File: news_paper 6.png | Format: PNG
# File: plastic_containers 53.png | Format: PNG
# File: glass 72.png | Format: PNG
# File: plastic_containers 119.png | Format: PNG
# File: plastic_containers 10.png | Format: PNG
# File: paper_cups 67.png | Format: PNG
# File: spray_cans 2.png | Format: PNG
# File: plastic_bottle 36.png | Format: PNG
# File: plastic_bag 184.png | Format: PNG
# File: glass 29.png | Format: PNG
# File: news_paper 178.png | Format: PNG
# File: paper 135.png | Format: PNG
# File: construction_scrap 59.png | Format: PNG
# File: glass 36.png | Format: PNG
# File: spray_cans 17.png | Format: PNG
# File: paper_cups 82.png | Format: PNG
# File: metal_objects 35.png | Format: PNG
# File: plastic_bag 49.png | Format: PNG
# File: plastic_containers 63.png | Format: PNG
# File: paper_cups 85.png | Format: PNG
# File: spray_cans 34.png | Format: PNG
# File: tetra_pak 78.png | Format: PNG
# File: construction_scrap 76.png | Format: PNG
# File: paper_cups 102.png | Format: PNG
# File: glass 106.png | Format: PNG
# File: plastic_bag 162.png | Format: PNG
# File: news_paper 12.png | Format: PNG
# File: news_paper 10.png | Format: PNG
# File: construction_scrap 6.png | Format: PNG
# File: glass 70.png | Format: PNG
# File: paper_cups 51.png | Format: PNG
# File: news_paper 93.png | Format: PNG
# File: plastic_bottle 74.png | Format: PNG
# File: metal_containers 12.png | Format: PNG
# File: plastic_bottle 54.png | Format: PNG
# File: paper 502.png | Format: PNG
# File: construction_scrap 44.png | Format: PNG
# File: paper_cups 95.png | Format: PNG
# File: beverage_cans 1.png | Format: PNG
# File: spray_cans 48.png | Format: PNG
# File: cardboard 5.png | Format: PNG
# File: paper_cups 22.png | Format: PNG
# File: beverage_cans 64.png | Format: PNG
# File: construction_scrap 82.png | Format: PNG
# File: plastic_bag 3.png | Format: PNG
# File: paper 39.png | Format: PNG
# File: tetra_pak 17.png | Format: PNG
# File: plastic_containers 107.png | Format: PNG
# File: beverage_cans 18.png | Format: PNG
# File: cardboard 92.png | Format: PNG
# File: plastic_bag 168.png | Format: PNG
# File: plastic_bottle 92.png | Format: PNG
# File: plastic_bottle 26.png | Format: PNG
# File: cardboard 49.png | Format: PNG
# File: cardboard 6.png | Format: PNG
# File: paper 121.png | Format: PNG
# File: plastic_bag 124.png | Format: PNG
# File: cardboard 83.png | Format: PNG
# File: glass 50.png | Format: PNG
# File: paper 125.png | Format: PNG
# File: news_paper 11.png | Format: PNG
# File: plastic_bottle 24.png | Format: PNG
# File: plastic_bottle 58.png | Format: PNG
# File: spray_cans 62.png | Format: PNG
# File: plastic_containers 67.png | Format: PNG
# File: paper_cups 69.png | Format: PNG
# File: news_paper 85.png | Format: PNG
# File: news_paper 91.png | Format: PNG
# File: paper 132.png | Format: PNG
# File: plastic_bottle 22.png | Format: PNG
# File: plastic_bottle 128.png | Format: PNG
# File: plastic_bag 429.png | Format: PNG
# File: tetra_pak 66.png | Format: PNG
# File: beverage_cans 21.png | Format: PNG
# File: paper 23.png | Format: PNG
# File: paper 66.png | Format: PNG
# File: cardboard 21.png | Format: PNG
# File: metal_containers 10.png | Format: PNG
# File: paper 62.png | Format: PNG
# File: paper_cups 80.png | Format: PNG
# File: plastic_bottle 130.png | Format: PNG
# File: metal_containers 96.png | Format: PNG
# File: glass 71.png | Format: PNG
# File: plastic_containers 92.png | Format: PNG
# File: paper 87.png | Format: PNG
# File: spray_cans 65.png | Format: PNG
# File: metal_containers 13.png | Format: PNG
# File: news_paper 5.png | Format: PNG
# File: plastic_containers 134.png | Format: PNG
# File: paper 117.png | Format: PNG
# File: cardboard 42.png | Format: PNG
# File: spray_cans 1.png | Format: PNG
# File: glass 64.png | Format: PNG
# File: tetra_pak 7.png | Format: PNG
# File: beverage_cans 12.png | Format: PNG
# File: glass 119.png | Format: PNG
# File: cardboard 102.png | Format: PNG
# File: metal_containers 2.png | Format: PNG
# File: glass 130.png | Format: PNG
# File: beverage_cans 4.png | Format: PNG
# File: plastic_containers 78.png | Format: PNG
# File: metal_containers 74.png | Format: PNG
# File: plastic_bottle 96.png | Format: PNG
# File: plastic_containers 3.png | Format: PNG
# File: spray_cans 46.png | Format: PNG
# File: paper_cups 76.png | Format: PNG
# File: tetra_pak 65.png | Format: PNG
# File: plastic_containers 58.png | Format: PNG
# File: paper_cups 17.png | Format: PNG
# File: plastic_bottle 147.png | Format: PNG
# File: paper 69.png | Format: PNG
# File: construction_scrap 80.png | Format: PNG
# File: plastic_bottle 118.png | Format: PNG
# File: cardboard 118.png | Format: PNG
# File: plastic_bag 47.png | Format: PNG
# File: plastic_bag 75.png | Format: PNG
# File: metal_objects 13.png | Format: PNG
# File: construction_scrap 56.png | Format: PNG
# File: paper_cups 59.png | Format: PNG
# File: news_paper 4.png | Format: PNG
# File: metal_objects 12.png | Format: PNG
# File: plastic_containers 64.png | Format: PNG
# File: paper_cups 24.png | Format: PNG
# File: metal_containers 82.png | Format: PNG
# File: paper_cups 48.png | Format: PNG
# File: spray_cans 117.png | Format: PNG
# File: plastic_bottle 99.png | Format: PNG
# File: news_paper 7.png | Format: PNG
# File: paper 130.png | Format: PNG
# File: glass 65.png | Format: PNG
# File: paper 133.png | Format: PNG
# File: beverage_cans 112.png | Format: PNG
# File: cardboard 93.png | Format: PNG
# File: plastic_bottle 85.png | Format: PNG
# File: glass 48.png | Format: PNG
# File: paper_cups 53.png | Format: PNG
# File: paper 113.png | Format: PNG
# File: paper_cups 97.png | Format: PNG
# File: plastic_bag 63.png | Format: PNG
# File: paper_cups 13.png | Format: PNG
# File: plastic_bottle 119.png | Format: PNG
# File: glass 103.png | Format: PNG
# File: glass 34.png | Format: PNG
# File: plastic_bag 81.png | Format: PNG
# File: glass 61.png | Format: PNG
# File: plastic_bottle 3.png | Format: PNG
# File: plastic_bag 73.png | Format: PNG
# File: cardboard 98.png | Format: PNG
# File: plastic_bag 40.png | Format: PNG
# File: spray_cans 33.png | Format: PNG
# File: metal_containers 60.png | Format: PNG
# File: paper_cups 11.png | Format: PNG
# File: plastic_containers 38.png | Format: PNG
# File: plastic_bottle 67.png | Format: PNG
# File: paper 50.png | Format: PNG
# File: beverage_cans 135.png | Format: PNG
# File: paper 52.png | Format: PNG
# File: glass 112.png | Format: PNG
# File: plastic_containers 32.png | Format: PNG
# File: spray_cans 28.png | Format: PNG
# File: spray_cans 43.png | Format: PNG
# File: cardboard 496.png | Format: PNG
# File: news_paper 94.png | Format: PNG
# File: glass 9.png | Format: PNG
# File: plastic_bottle 108.png | Format: PNG
# File: plastic_bag 158.png | Format: PNG
# File: plastic_bag 171.png | Format: PNG
# File: plastic_bottle 62.png | Format: PNG
# File: metal_objects 24.png | Format: PNG
# File: plastic_bag 23.png | Format: PNG
# File: paper_cups 66.png | Format: PNG
# File: metal_objects 38.png | Format: PNG
# File: news_paper 26.png | Format: PNG
# File: metal_objects 6.png | Format: PNG
# File: paper 1.png | Format: PNG
# File: paper 44.png | Format: PNG
# File: plastic_containers 111.png | Format: PNG
# File: plastic_bag 428.png | Format: PNG
# File: plastic_containers 116.png | Format: PNG
# File: metal_containers 40.png | Format: PNG
# File: beverage_cans 62.png | Format: PNG
# File: glass 4.png | Format: PNG
# File: plastic_bottle 131.png | Format: PNG
# File: glass 8.png | Format: PNG
# File: glass 131.png | Format: PNG
# File: paper 107.png | Format: PNG
# File: plastic_bottle 27.png | Format: PNG
# File: paper_cups 3.png | Format: PNG
# File: plastic_bag 37.png | Format: PNG
# File: news_paper 25.png | Format: PNG
# File: spray_cans 15.png | Format: PNG
# File: spray_cans 71.png | Format: PNG
# File: paper 505.png | Format: PNG
# File: beverage_cans 25.png | Format: PNG
# File: cardboard 27.png | Format: PNG
# File: paper 111.png | Format: PNG
# File: metal_containers 88.png | Format: PNG
# File: plastic_bottle 110.png | Format: PNG
# File: spray_cans 29.png | Format: PNG
# File: plastic_bottle 42.png | Format: PNG
# File: beverage_cans 60.png | Format: PNG
# File: plastic_containers 81.png | Format: PNG
# File: metal_containers 32.png | Format: PNG
# File: plastic_bag 114.png | Format: PNG
# File: beverage_cans 56.png | Format: PNG
# File: news_paper 76.png | Format: PNG
# File: plastic_bottle 124.png | Format: PNG
# File: metal_containers 83.png | Format: PNG
# File: plastic_bottle 71.png | Format: PNG
# File: cardboard 87.png | Format: PNG
# File: tetra_pak 55.png | Format: PNG
# File: plastic_containers 25.png | Format: PNG
# File: glass 17.png | Format: PNG
# File: plastic_containers 1.png | Format: PNG
# File: spray_cans 53.png | Format: PNG
# File: paper 18.png | Format: PNG
# File: plastic_bag 10.png | Format: PNG
# File: metal_containers 76.png | Format: PNG
# File: paper_cups 57.png | Format: PNG
# File: tetra_pak 10.png | Format: PNG
# File: paper_cups 86.png | Format: PNG
# File: plastic_bottle 121.png | Format: PNG
# File: plastic_containers 82.png | Format: PNG
# File: plastic_containers 127.png | Format: PNG
# File: tetra_pak 6.png | Format: PNG
# File: plastic_bag 123.png | Format: PNG
# File: paper 98.png | Format: PNG
# File: plastic_containers 29.png | Format: PNG
# File: cardboard 41.png | Format: PNG
# File: metal_containers 20.png | Format: PNG
# File: plastic_bottle 15.png | Format: PNG
# File: tetra_pak 73.png | Format: PNG
# File: spray_cans 55.png | Format: PNG
# File: paper 68.png | Format: PNG
# File: plastic_bottle 38.png | Format: PNG
# File: beverage_cans 22.png | Format: PNG
# File: spray_cans 57.png | Format: PNG
# File: paper 134.png | Format: PNG
# File: paper_cups 50.png | Format: PNG
# File: plastic_bag 159.png | Format: PNG
# File: construction_scrap 50.png | Format: PNG
# File: plastic_containers 102.png | Format: PNG
# File: plastic_bag 183.png | Format: PNG
# File: paper_cups 104.png | Format: PNG
# File: plastic_bottle 79.png | Format: PNG
# File: metal_containers 61.png | Format: PNG
# File: plastic_bottle 83.png | Format: PNG
# File: paper 71.png | Format: PNG
# File: spray_cans 11.png | Format: PNG
# File: glass 2.png | Format: PNG
# File: plastic_bottle 64.png | Format: PNG
# File: construction_scrap 3.png | Format: PNG
# File: beverage_cans 41.png | Format: PNG
# File: construction_scrap 42.png | Format: PNG
# File: construction_scrap 72.png | Format: PNG
# File: paper 12.png | Format: PNG
# File: cardboard 90.png | Format: PNG
# File: cardboard 94.png | Format: PNG
# File: paper 90.png | Format: PNG
# File: beverage_cans 48.png | Format: PNG
# File: metal_containers 27.png | Format: PNG
# File: construction_scrap 27.png | Format: PNG
# File: tetra_pak 25.png | Format: PNG
# File: tetra_pak 57.png | Format: PNG
# File: construction_scrap 45.png | Format: PNG
# File: plastic_bag 18.png | Format: PNG
# File: plastic_containers 90.png | Format: PNG
# File: plastic_bag 173.png | Format: PNG
# File: glass 21.png | Format: PNG
# File: glass 26.png | Format: PNG
# File: metal_objects 32.png | Format: PNG
# File: metal_containers 92.png | Format: PNG
# File: paper_cups 20.png | Format: PNG
# File: cardboard 103.png | Format: PNG
# File: plastic_bottle 127.png | Format: PNG
# File: plastic_containers 87.png | Format: PNG
# File: paper 38.png | Format: PNG
# File: glass 47.png | Format: PNG
# File: metal_objects 14.png | Format: PNG
# File: cardboard 54.png | Format: PNG
# File: plastic_bottle 12.png | Format: PNG
# File: news_paper 74.png | Format: PNG
# File: glass 14.png | Format: PNG
# File: tetra_pak 72.png | Format: PNG
# File: spray_cans 52.png | Format: PNG
# File: metal_containers 50.png | Format: PNG
# File: plastic_bag 163.png | Format: PNG
# File: cardboard 70.png | Format: PNG
# File: paper_cups 63.png | Format: PNG
# File: cardboard 46.png | Format: PNG
# File: plastic_bag 58.png | Format: PNG
# File: plastic_containers 121.png | Format: PNG
# File: plastic_bag 8.png | Format: PNG
# File: cardboard 28.png | Format: PNG
# File: news_paper 77.png | Format: PNG
# File: spray_cans 66.png | Format: PNG
# File: beverage_cans 40.png | Format: PNG
# File: metal_containers 3.png | Format: PNG
# File: glass 57.png | Format: PNG
# File: paper_cups 5.png | Format: PNG
# File: news_paper 78.png | Format: PNG
# File: plastic_containers 5.png | Format: PNG
# File: glass 67.png | Format: PNG
# File: spray_cans 10.png | Format: PNG
# File: glass 58.png | Format: PNG
# File: plastic_containers 56.png | Format: PNG
# File: news_paper 89.png | Format: PNG
# File: plastic_bag 53.png | Format: PNG
# File: spray_cans 44.png | Format: PNG
# File: spray_cans 21.png | Format: PNG
# File: metal_containers 80.png | Format: PNG
# File: plastic_bag 182.png | Format: PNG
# File: metal_containers 93.png | Format: PNG
# File: plastic_bag 68.png | Format: PNG
# File: tetra_pak 47.png | Format: PNG
# File: paper_cups 35.png | Format: PNG
# File: paper 106.png | Format: PNG
# File: construction_scrap 26.png | Format: PNG
# File: metal_objects 37.png | Format: PNG
# File: plastic_bag 139.png | Format: PNG
# File: paper 119.png | Format: PNG
# File: plastic_bag 138.png | Format: PNG
# File: paper_cups 101.png | Format: PNG
# File: metal_objects 27.png | Format: PNG
# File: beverage_cans 59.png | Format: PNG
# File: metal_objects 17.png | Format: PNG
# File: plastic_bottle 46.png | Format: PNG
# File: plastic_containers 128.png | Format: PNG
# File: paper_cups 54.png | Format: PNG
# File: plastic_bottle 5.png | Format: PNG
# File: cardboard 88.png | Format: PNG
# File: plastic_bottle 106.png | Format: PNG
# File: construction_scrap 65.png | Format: PNG
# File: plastic_bottle 19.png | Format: PNG
# File: plastic_containers 4.png | Format: PNG
# File: glass 113.png | Format: PNG
# File: plastic_bottle 68.png | Format: PNG
# File: plastic_bag 107.png | Format: PNG
# File: construction_scrap 62.png | Format: PNG
# File: paper_cups 19.png | Format: PNG
# File: metal_containers 75.png | Format: PNG
# File: construction_scrap 37.png | Format: PNG
# File: plastic_bag 111.png | Format: PNG
# File: plastic_bottle 102.png | Format: PNG
# File: plastic_bottle 4.png | Format: PNG
# File: paper 32.png | Format: PNG
# File: plastic_containers 88.png | Format: PNG
# File: plastic_containers 2.png | Format: PNG
# File: metal_containers 25.png | Format: PNG
# File: paper_cups 30.png | Format: PNG
# File: beverage_cans 29.png | Format: PNG
# File: plastic_bag 109.png | Format: PNG
# File: metal_objects 29.png | Format: PNG
# File: metal_containers 35.png | Format: PNG
# File: plastic_containers 22.png | Format: PNG
# File: glass 135.png | Format: PNG
# File: plastic_bottle 6.png | Format: PNG
# File: beverage_cans 74.png | Format: PNG
# File: plastic_bag 161.png | Format: PNG
# File: plastic_bottle 70.png | Format: PNG
# File: beverage_cans 45.png | Format: PNG
# File: cardboard 50.png | Format: PNG
# File: beverage_cans 2.png | Format: PNG
# File: glass 115.png | Format: PNG
# File: spray_cans 56.png | Format: PNG
# File: paper 97.png | Format: PNG
# File: plastic_bag 186.png | Format: PNG
# File: plastic_bag 44.png | Format: PNG
# File: paper 64.png | Format: PNG
# File: beverage_cans 53.png | Format: PNG
# File: paper_cups 26.png | Format: PNG
# File: glass 37.png | Format: PNG
# File: beverage_cans 20.png | Format: PNG
# File: plastic_bag 92.png | Format: PNG
# File: metal_objects 0.png | Format: PNG
# File: glass 78.png | Format: PNG
# File: news_paper 21.png | Format: PNG
# File: glass 46.png | Format: PNG
# File: metal_containers 43.png | Format: PNG
# File: beverage_cans 44.png | Format: PNG
# File: cardboard 9.png | Format: PNG
# File: cardboard 10.png | Format: PNG
# File: paper 81.png | Format: PNG
# File: paper 5.png | Format: PNG
# File: glass 56.png | Format: PNG
# File: metal_containers 8.png | Format: PNG
# File: plastic_bottle 61.png | Format: PNG
# File: beverage_cans 7.png | Format: PNG
# File: glass 98.png | Format: PNG
# File: beverage_cans 57.png | Format: PNG
# File: cardboard 51.png | Format: PNG
# File: metal_containers 1.png | Format: PNG
# File: beverage_cans 23.png | Format: PNG
# File: metal_containers 37.png | Format: PNG
# File: tetra_pak 32.png | Format: PNG
# File: cardboard 44.png | Format: PNG
# File: cardboard 117.png | Format: PNG
# File: spray_cans 5.png | Format: PNG
# File: plastic_bottle 39.png | Format: PNG
# File: paper_cups 37.png | Format: PNG
# File: paper 105.png | Format: PNG
# File: plastic_containers 95.png | Format: PNG
# File: glass 89.png | Format: PNG
# File: plastic_bottle 55.png | Format: PNG
# File: metal_containers 67.png | Format: PNG
# File: construction_scrap 29.png | Format: PNG
# File: plastic_bag 145.png | Format: PNG
# File: plastic_containers 57.png | Format: PNG
# File: glass 132.png | Format: PNG
# File: paper 82.png | Format: PNG
# File: spray_cans 39.png | Format: PNG
# File: construction_scrap 79.png | Format: PNG
# File: plastic_bag 150.png | Format: PNG
# File: news_paper 72.png | Format: PNG
# File: paper_cups 75.png | Format: PNG
# File: glass 104.png | Format: PNG
# File: glass 20.png | Format: PNG
# File: plastic_bottle 107.png | Format: PNG
# File: glass 95.png | Format: PNG
# File: plastic_containers 106.png | Format: PNG
# File: beverage_cans 27.png | Format: PNG
# File: plastic_bottle 132.png | Format: PNG
# File: paper_cups 27.png | Format: PNG
# File: paper_cups 44.png | Format: PNG
# File: spray_cans 68.png | Format: PNG
# File: plastic_bottle 89.png | Format: PNG
# File: spray_cans 59.png | Format: PNG
# File: paper 503.png | Format: PNG
# File: plastic_bottle 137.png | Format: PNG
# File: plastic_containers 45.png | Format: PNG
# File: paper 77.png | Format: PNG
# File: paper 55.png | Format: PNG
# File: plastic_bottle 20.png | Format: PNG
# File: construction_scrap 12.png | Format: PNG
# File: paper_cups 99.png | Format: PNG
# File: cardboard 89.png | Format: PNG
# File: glass 44.png | Format: PNG
# File: paper 504.png | Format: PNG
# File: plastic_bottle 115.png | Format: PNG
# File: beverage_cans 50.png | Format: PNG
# File: paper 73.png | Format: PNG
# File: plastic_bottle 50.png | Format: PNG
# File: paper 17.png | Format: PNG
# File: plastic_bottle 9.png | Format: PNG
# File: metal_containers 78.png | Format: PNG
# File: paper 110.png | Format: PNG
# File: metal_containers 57.png | Format: PNG
# File: plastic_containers 74.png | Format: PNG
# File: cardboard 59.png | Format: PNG
# File: metal_containers 29.png | Format: PNG
# File: cardboard 20.png | Format: PNG
# File: news_paper 14.png | Format: PNG
# File: construction_scrap 51.png | Format: PNG
# File: paper_cups 18.png | Format: PNG
# File: construction_scrap 28.png | Format: PNG
# File: paper_cups 105.png | Format: PNG
# File: metal_containers 23.png | Format: PNG
# File: plastic_bottle 81.png | Format: PNG
# File: paper_cups 8.png | Format: PNG
# File: tetra_pak 59.png | Format: PNG
# File: paper 112.png | Format: PNG
# File: glass 110.png | Format: PNG
# File: plastic_bag 117.png | Format: PNG
# File: plastic_containers 60.png | Format: PNG
# File: plastic_containers 86.png | Format: PNG
# File: construction_scrap 34.png | Format: PNG
# File: paper 78.png | Format: PNG
# File: tetra_pak 64.png | Format: PNG
# File: spray_cans 6.png | Format: PNG
# File: plastic_containers 105.png | Format: PNG
# File: metal_objects 11.png | Format: PNG
# File: plastic_bag 104.png | Format: PNG
# File: tetra_pak 4.png | Format: PNG
# File: construction_scrap 20.png | Format: PNG
# File: paper_cups 36.png | Format: PNG
# File: metal_objects 40.png | Format: PNG
# File: cardboard 95.png | Format: PNG
# File: plastic_bag 126.png | Format: PNG
# File: paper_cups 31.png | Format: PNG
# File: beverage_cans 33.png | Format: PNG
# File: plastic_bag 91.png | Format: PNG
# File: cardboard 112.png | Format: PNG
# File: plastic_bottle 97.png | Format: PNG
# File: cardboard 97.png | Format: PNG
# File: metal_containers 28.png | Format: PNG
# File: paper 85.png | Format: PNG
# File: metal_containers 30.png | Format: PNG
# File: glass 81.png | Format: PNG
# File: plastic_containers 131.png | Format: PNG
# File: metal_objects 39.png | Format: PNG
# File: glass 102.png | Format: PNG
# File: plastic_containers 112.png | Format: PNG
# File: cardboard 60.png | Format: PNG
# File: paper 27.png | Format: PNG
# File: plastic_containers 180.png | Format: PNG
# File: beverage_cans 47.png | Format: PNG
# File: paper_cups 25.png | Format: PNG
# File: spray_cans 67.png | Format: PNG
# File: construction_scrap 69.png | Format: PNG
# File: metal_containers 45.png | Format: PNG
# File: spray_cans 12.png | Format: PNG
# File: beverage_cans 30.png | Format: PNG
# File: paper_cups 84.png | Format: PNG
# File: glass 60.png | Format: PNG
# File: tetra_pak 11.png | Format: PNG
# File: plastic_bottle 59.png | Format: PNG
# File: construction_scrap 2.png | Format: PNG
# File: glass 5.png | Format: PNG
# File: plastic_containers 104.png | Format: PNG
# File: tetra_pak 40.png | Format: PNG
# File: paper 24.png | Format: PNG
# File: tetra_pak 26.png | Format: PNG
# File: paper 93.png | Format: PNG
# File: news_paper 22.png | Format: PNG
# File: paper 70.png | Format: PNG
# File: plastic_containers 126.png | Format: PNG
# File: construction_scrap 9.png | Format: PNG
# File: plastic_bottle 82.png | Format: PNG
# File: beverage_cans 51.png | Format: PNG
# File: plastic_containers 59.png | Format: PNG
# File: glass 54.png | Format: PNG
# File: paper 76.png | Format: PNG
# File: construction_scrap 39.png | Format: PNG
# File: plastic_bag 165.png | Format: PNG
# File: paper 4.png | Format: PNG
# File: glass 84.png | Format: PNG
# File: plastic_bag 102.png | Format: PNG
# File: construction_scrap 19.png | Format: PNG
# File: plastic_containers 175.png | Format: PNG
# File: paper_cups 92.png | Format: PNG
# File: plastic_containers 70.png | Format: PNG
# File: spray_cans 9.png | Format: PNG
# File: metal_objects 33.png | Format: PNG
# File: plastic_containers 71.png | Format: PNG
# File: cardboard 35.png | Format: PNG
# File: plastic_bag 427.png | Format: PNG
# File: plastic_bag 101.png | Format: PNG
# File: paper_cups 41.png | Format: PNG
# File: plastic_bag 112.png | Format: PNG
# File: construction_scrap 25.png | Format: PNG
# File: plastic_bag 43.png | Format: PNG
# File: plastic_containers 129.png | Format: PNG
# File: paper_cups 12.png | Format: PNG
# File: news_paper 180.png | Format: PNG
# File: paper 49.png | Format: PNG
# File: metal_objects 8.png | Format: PNG
# File: tetra_pak 20.png | Format: PNG
# File: paper 33.png | Format: PNG
# File: news_paper 3.png | Format: PNG
# File: plastic_bag 136.png | Format: PNG
# File: paper_cups 0.png | Format: PNG
# File: plastic_containers 118.png | Format: PNG
# File: cardboard 82.png | Format: PNG
# File: plastic_bag 153.png | Format: PNG
# File: news_paper 16.png | Format: PNG
# File: beverage_cans 55.png | Format: PNG
# File: tetra_pak 27.png | Format: PNG
# File: paper_cups 29.png | Format: PNG
# File: paper 128.png | Format: PNG
# File: tetra_pak 29.png | Format: PNG
# File: metal_containers 73.png | Format: PNG
# File: construction_scrap 64.png | Format: PNG
# File: plastic_bottle 40.png | Format: PNG
# File: metal_containers 14.png | Format: PNG
# File: plastic_containers 177.png | Format: PNG
# File: spray_cans 0.png | Format: PNG
# File: glass 136.png | Format: PNG
# File: plastic_containers 6.png | Format: PNG
# File: paper 129.png | Format: PNG
# File: paper 26.png | Format: PNG
# File: paper_cups 88.png | Format: PNG
# File: paper_cups 65.png | Format: PNG
# File: spray_cans 20.png | Format: PNG
# File: plastic_bottle 51.png | Format: PNG
# File: cardboard 492.png | Format: PNG
# File: tetra_pak 18.png | Format: PNG
# File: paper 65.png | Format: PNG
# File: news_paper 33.png | Format: PNG
# File: beverage_cans 9.png | Format: PNG
# File: glass 90.png | Format: PNG
# File: spray_cans 18.png | Format: PNG
# File: plastic_containers 83.png | Format: PNG
# File: spray_cans 8.png | Format: PNG
# File: plastic_bottle 49.png | Format: PNG
# File: paper 31.png | Format: PNG
# File: plastic_containers 55.png | Format: PNG
# File: construction_scrap 5.png | Format: PNG
# File: glass 118.png | Format: PNG
# File: beverage_cans 75.png | Format: PNG
# File: news_paper 80.png | Format: PNG
# File: glass 74.png | Format: PNG
# File: metal_objects 16.png | Format: PNG
# File: spray_cans 76.png | Format: PNG
# File: tetra_pak 79.png | Format: PNG
# File: plastic_containers 125.png | Format: PNG
# File: tetra_pak 0.png | Format: PNG
# File: plastic_bottle 111.png | Format: PNG
# File: paper 60.png | Format: PNG
# File: beverage_cans 5.png | Format: PNG
# File: metal_containers 18.png | Format: PNG
# File: construction_scrap 84.png | Format: PNG
# File: spray_cans 54.png | Format: PNG
# File: beverage_cans 32.png | Format: PNG
# File: plastic_bottle 105.png | Format: PNG
# File: glass 105.png | Format: PNG
# File: construction_scrap 18.png | Format: PNG
# File: paper 15.png | Format: PNG
# File: spray_cans 30.png | Format: PNG
# File: metal_containers 81.png | Format: PNG
# File: glass 83.png | Format: PNG
# File: paper_cups 90.png | Format: PNG
# File: metal_containers 66.png | Format: PNG
# File: tetra_pak 63.png | Format: PNG
# File: cardboard 39.png | Format: PNG
# File: construction_scrap 31.png | Format: PNG
# File: plastic_bottle 104.png | Format: PNG
# File: glass 116.png | Format: PNG
# File: plastic_bottle 90.png | Format: PNG
# File: metal_containers 11.png | Format: PNG
# File: paper 104.png | Format: PNG
# File: paper_cups 98.png | Format: PNG
# File: glass 128.png | Format: PNG
# File: paper_cups 106.png | Format: PNG
# File: metal_objects 34.png | Format: PNG
# File: metal_objects 36.png | Format: PNG
# File: plastic_bottle 91.png | Format: PNG
# File: paper_cups 91.png | Format: PNG
# File: paper 40.png | Format: PNG
# File: plastic_bottle 32.png | Format: PNG
# File: plastic_containers 99.png | Format: PNG
# File: paper 86.png | Format: PNG
# File: beverage_cans 24.png | Format: PNG
# File: plastic_containers 7.png | Format: PNG
# File: paper_cups 21.png | Format: PNG
# File: plastic_containers 18.png | Format: PNG
# File: paper 45.png | Format: PNG
# File: metal_containers 47.png | Format: PNG
# File: plastic_bottle 35.png | Format: PNG
# File: plastic_bottle 33.png | Format: PNG
# File: cardboard 75.png | Format: PNG
# File: metal_containers 54.png | Format: PNG
# File: paper 59.png | Format: PNG
# File: beverage_cans 26.png | Format: PNG
# File: paper 47.png | Format: PNG
# File: paper_cups 1.png | Format: PNG
# File: metal_objects 20.png | Format: PNG
# File: plastic_bag 131.png | Format: PNG
# File: paper 11.png | Format: PNG
# File: cardboard 66.png | Format: PNG
# File: paper_cups 103.png | Format: PNG
# File: tetra_pak 19.png | Format: PNG
# File: spray_cans 74.png | Format: PNG
# File: plastic_bottle 112.png | Format: PNG
# File: cardboard 43.png | Format: PNG
# File: spray_cans 36.png | Format: PNG
# File: tetra_pak 22.png | Format: PNG
# File: paper 7.png | Format: PNG
# File: spray_cans 25.png | Format: PNG
# File: plastic_bag 95.png | Format: PNG
# File: plastic_containers 100.png | Format: PNG
# File: spray_cans 3.png | Format: PNG
# File: paper 124.png | Format: PNG
# File: beverage_cans 68.png | Format: PNG
# File: news_paper 98.png | Format: PNG
# File: plastic_containers 115.png | Format: PNG
# File: plastic_bottle 145.png | Format: PNG
# File: construction_scrap 75.png | Format: PNG
# File: paper 13.png | Format: PNG
# File: cardboard 48.png | Format: PNG
# File: tetra_pak 31.png | Format: PNG
# File: plastic_bottle 69.png | Format: PNG
# File: metal_containers 55.png | Format: PNG
# File: plastic_bag 74.png | Format: PNG
# File: cardboard 74.png | Format: PNG
# File: plastic_bag 121.png | Format: PNG
# File: metal_objects 21.png | Format: PNG
# File: metal_containers 68.png | Format: PNG
# File: paper 58.png | Format: PNG
# File: cardboard 2.png | Format: PNG
# File: glass 40.png | Format: PNG
# File: plastic_bottle 30.png | Format: PNG
# File: tetra_pak 1.png | Format: PNG
# File: plastic_bottle 135.png | Format: PNG
# File: news_paper 90.png | Format: PNG
# File: plastic_containers 103.png | Format: PNG
# File: metal_containers 100.png | Format: PNG
# File: cardboard 490.png | Format: PNG
# File: plastic_bag 27.png | Format: PNG
# File: plastic_containers 77.png | Format: PNG
# File: metal_objects 26.png | Format: PNG
# File: plastic_containers 94.png | Format: PNG
# File: news_paper 15.png | Format: PNG
# File: construction_scrap 21.png | Format: PNG
# File: news_paper 105.png | Format: PNG
# File: spray_cans 19.png | Format: PNG
# File: paper 41.png | Format: PNG
# File: cardboard 81.png | Format: PNG
# File: glass 45.png | Format: PNG
# File: glass 18.png | Format: PNG
# File: tetra_pak 60.png | Format: PNG
# File: plastic_containers 31.png | Format: PNG
# File: construction_scrap 48.png | Format: PNG
# File: tetra_pak 2.png | Format: PNG
# File: construction_scrap 35.png | Format: PNG
# File: paper 94.png | Format: PNG
# File: beverage_cans 0.png | Format: PNG
# File: plastic_bottle 47.png | Format: PNG
# File: tetra_pak 62.png | Format: PNG
# File: plastic_bag 32.png | Format: PNG
# File: metal_containers 46.png | Format: PNG
# File: metal_containers 9.png | Format: PNG
# File: metal_containers 71.png | Format: PNG
# File: beverage_cans 69.png | Format: PNG
# File: construction_scrap 83.png | Format: PNG
# File: plastic_bottle 1.png | Format: PNG
# File: metal_containers 15.png | Format: PNG
# File: cardboard 73.png | Format: PNG
# File: plastic_bag 141.png | Format: PNG
# File: cardboard 91.png | Format: PNG
# File: glass 76.png | Format: PNG
# File: news_paper 79.png | Format: PNG
# File: paper 95.png | Format: PNG
# File: metal_containers 21.png | Format: PNG
# File: paper 51.png | Format: PNG
# File: glass 53.png | Format: PNG
# File: plastic_bag 178.png | Format: PNG
# File: glass 12.png | Format: PNG
# File: paper_cups 70.png | Format: PNG
# File: paper 80.png | Format: PNG
# File: metal_objects 31.png | Format: PNG
# File: tetra_pak 41.png | Format: PNG
# File: plastic_containers 27.png | Format: PNG
# File: metal_containers 56.png | Format: PNG
# File: paper 79.png | Format: PNG
# File: news_paper 87.png | Format: PNG
# File: plastic_bottle 63.png | Format: PNG
# File: th - 2025-02-09T105707.959.png | Format: PNG
# File: th - 2025-02-09T105626.440 - Copy.png | Format: PNG
# File: th - 2025-02-09T105059.203 - Copy.png | Format: PNG
# File: th - 2025-02-09T105637.495.png | Format: PNG
# File: th - 2025-02-09T105629.480.png | Format: PNG
# File: th - 2025-02-09T105624.209.png | Format: PNG
# File: th - 2025-02-09T104045.120 - Copy.png | Format: PNG
# File: th - 2025-02-09T105623.240 - Copy.png | Format: PNG
# File: th - 2025-02-09T105113.484.png | Format: PNG
# File: th - 2025-02-09T105619.724 - Copy.png | Format: PNG
# File: th - 2025-02-09T105115.302 - Copy.png | Format: PNG
# File: th - 2025-02-09T105127.089 - Copy.png | Format: PNG
# File: th - 2025-02-09T104102.860.png | Format: PNG
# File: th - 2025-02-09T104057.337.png | Format: PNG
# File: th - 2025-02-09T105628.213.png | Format: PNG
# File: th - 2025-02-09T104052.710 - Copy.png | Format: PNG
# File: th - 2025-02-09T104051.603 - Copy.png | Format: PNG
# File: th - 2025-02-09T105128.808 - Copy.png | Format: PNG
# ...
# File: gloves 323.png | Format: PNG
# File: masks 452.png | Format: PNG
# File: syringe 312.png | Format: PNG
# File: masks 26.png | Format: PNG
# File: masks 6.png | Format: PNG
# File: syringe 26.png | Format: PNG
# File: masks 382.png | Format: PNG
# File: medicines 446.png | Format: PNG
# File: masks 422.png | Format: PNG
# File: medicines 223.png | Format: PNG
# File: syringe 320.png | Format: PNG
# File: medicines 493.png | Format: PNG
# File: gloves 337.png | Format: PNG
# File: syringe 131.png | Format: PNG
# File: masks 224.png | Format: PNG
# File: medicines 444.png | Format: PNG
# File: syringe 147.png | Format: PNG
# File: masks 496.png | Format: PNG
# File: medicines 503.png | Format: PNG
# File: medicines 422.png | Format: PNG
# File: masks 459.png | Format: PNG
# File: syringe 149.png | Format: PNG
# File: gloves 113.png | Format: PNG
# File: masks 249.png | Format: PNG
# File: medicines 374.png | Format: PNG
# File: gloves 45.png | Format: PNG
# File: masks 445.png | Format: PNG
# File: syringe 420.png | Format: PNG
# File: syringe 311.png | Format: PNG
# File: gloves 442.png | Format: PNG
# File: medicines 234.png | Format: PNG
# File: masks 113.png | Format: PNG
# File: medicines 161.png | Format: PNG
# File: syringe 423.png | Format: PNG
# File: medicines 240.png | Format: PNG
# File: masks 314.png | Format: PNG
# File: gloves 17.png | Format: PNG
# File: gloves 171.png | Format: PNG
# File: masks 329.png | Format: PNG
# File: medicines 5.png | Format: PNG
# File: masks 187.png | Format: PNG
# File: syringe 35.png | Format: PNG
# File: syringe 371.png | Format: PNG
# File: gloves 35.png | Format: PNG
# File: masks 334.png | Format: PNG
# File: medicines 215.png | Format: PNG
# File: syringe 268.png | Format: PNG
# File: syringe 281.png | Format: PNG
# File: medicines 207.png | Format: PNG
# File: masks 447.png | Format: PNG
# File: syringe 123.png | Format: PNG
# File: medicines 48.png | Format: PNG
# File: masks 172.png | Format: PNG
# File: syringe 168.png | Format: PNG
# File: masks 65.png | Format: PNG
# File: masks 285.png | Format: PNG
# File: syringe 421.png | Format: PNG
# File: gloves 74.png | Format: PNG
# File: masks 188.png | Format: PNG
# File: syringe 278.png | Format: PNG
# File: gloves 32.png | Format: PNG
# File: medicines 369.png | Format: PNG
# File: syringe 227.png | Format: PNG
# File: masks 312.png | Format: PNG
# File: masks 313.png | Format: PNG
# File: gloves 327.png | Format: PNG
# File: medicines 458.png | Format: PNG
# File: masks 427.png | Format: PNG
# File: medicines 305.png | Format: PNG
# File: masks 3.png | Format: PNG
# File: masks 328.png | Format: PNG
# File: syringe 272.png | Format: PNG
# File: gloves 252.png | Format: PNG
# File: gloves 381.png | Format: PNG
# File: medicines 193.png | Format: PNG
# File: masks 234.png | Format: PNG
# File: masks 311.png | Format: PNG
# File: medicines 23.png | Format: PNG
# File: gloves 155.png | Format: PNG
# File: medicines 98.png | Format: PNG
# File: masks 48.png | Format: PNG
# File: medicines 136.png | Format: PNG
# File: medicines 441.png | Format: PNG
# File: masks 254.png | Format: PNG
# File: medicines 367.png | Format: PNG
# File: gloves 287.png | Format: PNG
# File: medicines 461.png | Format: PNG
# File: syringe 347.png | Format: PNG
# File: masks 268.png | Format: PNG
# File: syringe 293.png | Format: PNG
# File: syringe 386.png | Format: PNG
# File: syringe 396.png | Format: PNG
# File: syringe 257.png | Format: PNG
# File: medicines 228.png | Format: PNG
# File: masks 243.png | Format: PNG
# File: medicines 137.png | Format: PNG
# File: gloves 234.png | Format: PNG
# File: gloves 342.png | Format: PNG
# File: medicines 437.png | Format: PNG
# File: masks 327.png | Format: PNG
# File: masks 323.png | Format: PNG
# File: syringe 29.png | Format: PNG
# File: masks 104.png | Format: PNG
# File: medicines 93.png | Format: PNG
# File: syringe 495.png | Format: PNG
# File: syringe 249.png | Format: PNG
# File: masks 389.png | Format: PNG
# File: syringe 44.png | Format: PNG
# File: medicines 100.png | Format: PNG
# File: medicines 212.png | Format: PNG
# File: medicines 73.png | Format: PNG
# File: masks 315.png | Format: PNG
# File: syringe 164.png | Format: PNG
# File: masks 407.png | Format: PNG
# File: masks 337.png | Format: PNG
# File: syringe 62.png | Format: PNG
# File: gloves 256.png | Format: PNG
# File: masks 274.png | Format: PNG
# File: gloves 434.png | Format: PNG
# File: medicines 30.png | Format: PNG
# File: masks 150.png | Format: PNG
# File: medicines 154.png | Format: PNG
# File: medicines 127.png | Format: PNG
# File: masks 441.png | Format: PNG
# File: masks 305.png | Format: PNG
# File: syringe 329.png | Format: PNG
# File: masks 13.png | Format: PNG
# File: gloves 418.png | Format: PNG
# File: gloves 346.png | Format: PNG
# File: syringe 100.png | Format: PNG
# File: gloves 104.png | Format: PNG
# File: syringe 498.png | Format: PNG
# File: syringe 12.png | Format: PNG
# File: masks 200.png | Format: PNG
# File: medicines 373.png | Format: PNG
# File: masks 397.png | Format: PNG
# File: gloves 240.png | Format: PNG
# File: masks 175.png | Format: PNG
# File: masks 136.png | Format: PNG
# File: masks 304.png | Format: PNG
# File: gloves 78.png | Format: PNG
# File: syringe 96.png | Format: PNG
# File: syringe 34.png | Format: PNG
# File: medicines 248.png | Format: PNG
# File: masks 227.png | Format: PNG
# File: gloves 408.png | Format: PNG
# File: masks 220.png | Format: PNG
# File: syringe 304.png | Format: PNG
# File: masks 15.png | Format: PNG
# File: gloves 222.png | Format: PNG
# File: syringe 210.png | Format: PNG
# File: gloves 13.png | Format: PNG
# File: masks 486.png | Format: PNG
# File: masks 110.png | Format: PNG
# File: medicines 13.png | Format: PNG
# File: medicines 208.png | Format: PNG
# File: masks 18.png | Format: PNG
# File: gloves 97.png | Format: PNG
# File: gloves 60.png | Format: PNG
# File: masks 428.png | Format: PNG
# File: masks 321.png | Format: PNG
# File: masks 353.png | Format: PNG
# File: medicines 239.png | Format: PNG
# File: gloves 427.png | Format: PNG
# File: gloves 91.png | Format: PNG
# File: medicines 346.png | Format: PNG
# File: syringe 413.png | Format: PNG
# File: medicines 499.png | Format: PNG
# File: gloves 53.png | Format: PNG
# File: gloves 71.png | Format: PNG
# File: masks 238.png | Format: PNG
# File: syringe 83.png | Format: PNG
# File: gloves 293.png | Format: PNG
# File: medicines 475.png | Format: PNG
# File: syringe 503.png | Format: PNG
# File: masks 170.png | Format: PNG
# File: syringe 41.png | Format: PNG
# File: medicines 501.png | Format: PNG
# File: masks 198.png | Format: PNG
# File: gloves 303.png | Format: PNG
# File: syringe 418.png | Format: PNG
# File: medicines 121.png | Format: PNG
# File: medicines 347.png | Format: PNG
# File: syringe 188.png | Format: PNG
# File: medicines 46.png | Format: PNG
# File: masks 115.png | Format: PNG
# File: syringe 116.png | Format: PNG
# File: masks 149.png | Format: PNG
# File: gloves 87.png | Format: PNG
# File: gloves 345.png | Format: PNG
# File: masks 472.png | Format: PNG
# File: masks 83.png | Format: PNG
# File: gloves 411.png | Format: PNG
# File: gloves 304.png | Format: PNG
# File: syringe 427.png | Format: PNG
# File: medicines 209.png | Format: PNG
# File: masks 375.png | Format: PNG
# File: medicines 165.png | Format: PNG
# File: gloves 207.png | Format: PNG
# File: masks 493.png | Format: PNG
# File: medicines 320.png | Format: PNG
# File: syringe 104.png | Format: PNG
# File: masks 196.png | Format: PNG
# File: syringe 127.png | Format: PNG
# File: medicines 97.png | Format: PNG
# File: gloves 402.png | Format: PNG
# File: syringe 388.png | Format: PNG
# File: gloves 269.png | Format: PNG
# File: medicines 366.png | Format: PNG
# File: masks 417.png | Format: PNG
# File: medicines 230.png | Format: PNG
# File: masks 219.png | Format: PNG
# File: masks 418.png | Format: PNG
# File: gloves 338.png | Format: PNG
# File: gloves 20.png | Format: PNG
# File: medicines 300.png | Format: PNG
# File: medicines 262.png | Format: PNG
# File: masks 96.png | Format: PNG
# File: syringe 98.png | Format: PNG
# File: gloves 278.png | Format: PNG
# File: syringe 496.png | Format: PNG
# File: gloves 81.png | Format: PNG
# File: gloves 218.png | Format: PNG
# File: medicines 238.png | Format: PNG
# File: gloves 245.png | Format: PNG
# File: masks 272.png | Format: PNG
# File: gloves 428.png | Format: PNG
# File: syringe 446.png | Format: PNG
# File: syringe 322.png | Format: PNG
# File: gloves 357.png | Format: PNG
# File: masks 338.png | Format: PNG
# File: gloves 3.png | Format: PNG
# File: syringe 308.png | Format: PNG
# File: masks 191.png | Format: PNG
# File: medicines 29.png | Format: PNG
# File: medicines 389.png | Format: PNG
# File: medicines 302.png | Format: PNG
# File: masks 235.png | Format: PNG
# File: masks 492.png | Format: PNG
# File: medicines 448.png | Format: PNG
# File: gloves 353.png | Format: PNG
# File: gloves 443.png | Format: PNG
# File: syringe 25.png | Format: PNG
# File: masks 79.png | Format: PNG
# File: gloves 89.png | Format: PNG
# File: masks 143.png | Format: PNG
# File: gloves 291.png | Format: PNG
# File: medicines 2.png | Format: PNG
# File: gloves 246.png | Format: PNG
# File: gloves 18.png | Format: PNG
# File: masks 257.png | Format: PNG
# File: masks 395.png | Format: PNG
# File: masks 204.png | Format: PNG
# File: medicines 204.png | Format: PNG
# File: masks 283.png | Format: PNG
# File: gloves 213.png | Format: PNG
# File: masks 39.png | Format: PNG
# File: gloves 254.png | Format: PNG
# File: masks 270.png | Format: PNG
# File: syringe 470.png | Format: PNG
# File: masks 178.png | Format: PNG
# File: gloves 356.png | Format: PNG
# File: medicines 188.png | Format: PNG
# File: masks 69.png | Format: PNG
# File: masks 47.png | Format: PNG
# File: medicines 132.png | Format: PNG
# File: medicines 415.png | Format: PNG
# File: masks 402.png | Format: PNG
# File: masks 194.png | Format: PNG
# File: masks 186.png | Format: PNG
# File: masks 230.png | Format: PNG
# File: gloves 314.png | Format: PNG
# File: masks 280.png | Format: PNG
# File: syringe 307.png | Format: PNG
# File: masks 217.png | Format: PNG
# File: gloves 430.png | Format: PNG
# File: medicines 18.png | Format: PNG
# File: medicines 196.png | Format: PNG
# File: masks 45.png | Format: PNG
# File: masks 302.png | Format: PNG
# File: medicines 194.png | Format: PNG
# File: syringe 120.png | Format: PNG
# File: syringe 314.png | Format: PNG
# File: gloves 100.png | Format: PNG
# File: masks 17.png | Format: PNG
# File: gloves 199.png | Format: PNG
# File: medicines 331.png | Format: PNG
# File: medicines 108.png | Format: PNG
# File: syringe 0.png | Format: PNG
# File: medicines 250.png | Format: PNG
# File: masks 85.png | Format: PNG
# File: medicines 327.png | Format: PNG
# File: medicines 483.png | Format: PNG
# File: gloves 79.png | Format: PNG
# File: syringe 48.png | Format: PNG
# File: syringe 359.png | Format: PNG
# File: masks 108.png | Format: PNG
# File: gloves 205.png | Format: PNG
# File: medicines 40.png | Format: PNG
# File: masks 248.png | Format: PNG
# File: syringe 280.png | Format: PNG
# File: medicines 123.png | Format: PNG
# File: gloves 7.png | Format: PNG
# File: syringe 291.png | Format: PNG
# File: medicines 312.png | Format: PNG
# File: medicines 379.png | Format: PNG
# File: masks 411.png | Format: PNG
# File: masks 494.png | Format: PNG
# File: masks 67.png | Format: PNG
# File: masks 88.png | Format: PNG
# File: medicines 9.png | Format: PNG
# File: gloves 243.png | Format: PNG
# File: medicines 473.png | Format: PNG
# File: masks 431.png | Format: PNG
# File: masks 352.png | Format: PNG
# File: gloves 0.png | Format: PNG
# File: syringe 262.png | Format: PNG
# File: masks 316.png | Format: PNG
# File: masks 12.png | Format: PNG
# File: masks 80.png | Format: PNG
# File: syringe 487.png | Format: PNG
# File: syringe 244.png | Format: PNG
# File: syringe 133.png | Format: PNG
# File: medicines 442.png | Format: PNG
# File: masks 34.png | Format: PNG
# File: syringe 453.png | Format: PNG
# File: medicines 457.png | Format: PNG
# File: syringe 417.png | Format: PNG
# File: masks 269.png | Format: PNG
# File: medicines 334.png | Format: PNG
# File: masks 1.png | Format: PNG
# File: medicines 28.png | Format: PNG
# File: syringe 430.png | Format: PNG
# File: syringe 254.png | Format: PNG
# File: medicines 237.png | Format: PNG
# File: gloves 322.png | Format: PNG
# File: gloves 55.png | Format: PNG
# File: masks 471.png | Format: PNG
# File: syringe 15.png | Format: PNG
# File: gloves 46.png | Format: PNG
# File: medicines 244.png | Format: PNG
# File: syringe 287.png | Format: PNG
# File: masks 183.png | Format: PNG
# File: medicines 431.png | Format: PNG
# File: masks 359.png | Format: PNG
# File: gloves 40.png | Format: PNG
# File: masks 341.png | Format: PNG
# File: medicines 222.png | Format: PNG
# File: syringe 49.png | Format: PNG
# File: masks 324.png | Format: PNG
# File: syringe 158.png | Format: PNG
# File: syringe 411.png | Format: PNG
# File: masks 432.png | Format: PNG
# File: medicines 450.png | Format: PNG
# File: medicines 492.png | Format: PNG
# File: medicines 486.png | Format: PNG
# File: gloves 239.png | Format: PNG
# File: gloves 102.png | Format: PNG
# File: masks 296.png | Format: PNG
# File: medicines 135.png | Format: PNG
# File: syringe 243.png | Format: PNG
# File: medicines 171.png | Format: PNG
# File: masks 297.png | Format: PNG
# File: masks 434.png | Format: PNG
# File: syringe 144.png | Format: PNG
# File: medicines 337.png | Format: PNG
# File: syringe 154.png | Format: PNG
# File: masks 442.png | Format: PNG
# File: syringe 126.png | Format: PNG
# File: medicines 252.png | Format: PNG
# File: masks 52.png | Format: PNG
# File: masks 398.png | Format: PNG
# File: medicines 113.png | Format: PNG
# File: masks 232.png | Format: PNG
# File: medicines 296.png | Format: PNG
# File: syringe 412.png | Format: PNG
# File: gloves 186.png | Format: PNG
# File: masks 237.png | Format: PNG
# File: gloves 147.png | Format: PNG
# File: gloves 86.png | Format: PNG
# File: masks 180.png | Format: PNG
# File: medicines 151.png | Format: PNG
# File: medicines 471.png | Format: PNG
# File: masks 339.png | Format: PNG
# File: gloves 232.png | Format: PNG
# File: medicines 365.png | Format: PNG
# File: medicines 335.png | Format: PNG
# File: masks 8.png | Format: PNG
# File: masks 76.png | Format: PNG
# File: masks 30.png | Format: PNG
# File: gloves 310.png | Format: PNG
# File: masks 414.png | Format: PNG
# File: syringe 426.png | Format: PNG
# File: masks 121.png | Format: PNG
# File: masks 420.png | Format: PNG
# File: masks 233.png | Format: PNG
# File: medicines 92.png | Format: PNG
# File: masks 176.png | Format: PNG
# File: masks 450.png | Format: PNG
# File: medicines 342.png | Format: PNG
# File: medicines 370.png | Format: PNG
# File: syringe 442.png | Format: PNG
# File: syringe 474.png | Format: PNG
# File: medicines 505.png | Format: PNG
# File: masks 457.png | Format: PNG
# File: masks 317.png | Format: PNG
# File: medicines 3.png | Format: PNG
# File: gloves 187.png | Format: PNG
# File: medicines 307.png | Format: PNG
# File: syringe 355.png | Format: PNG
# File: masks 216.png | Format: PNG
# File: masks 463.png | Format: PNG
# File: medicines 182.png | Format: PNG
# File: gloves 302.png | Format: PNG
# File: gloves 217.png | Format: PNG
# File: masks 228.png | Format: PNG
# File: gloves 151.png | Format: PNG
# File: masks 51.png | Format: PNG
# File: masks 345.png | Format: PNG
# File: gloves 228.png | Format: PNG
# File: gloves 16.png | Format: PNG
# File: medicines 434.png | Format: PNG
# File: masks 363.png | Format: PNG
# File: syringe 43.png | Format: PNG
# File: syringe 271.png | Format: PNG
# File: masks 209.png | Format: PNG
# File: syringe 117.png | Format: PNG
# File: syringe 317.png | Format: PNG
# File: medicines 484.png | Format: PNG
# File: gloves 424.png | Format: PNG
# File: medicines 210.png | Format: PNG
# File: syringe 258.png | Format: PNG
# File: syringe 394.png | Format: PNG
# File: gloves 371.png | Format: PNG
# File: medicines 202.png | Format: PNG
# File: medicines 378.png | Format: PNG
# File: medicines 34.png | Format: PNG
# File: syringe 121.png | Format: PNG
# File: gloves 83.png | Format: PNG
# File: medicines 88.png | Format: PNG
# File: masks 478.png | Format: PNG
# File: medicines 217.png | Format: PNG
# File: syringe 480.png | Format: PNG
# File: masks 366.png | Format: PNG
# File: gloves 315.png | Format: PNG
# File: masks 81.png | Format: PNG
# File: medicines 185.png | Format: PNG
# File: syringe 269.png | Format: PNG
# File: medicines 343.png | Format: PNG
# File: masks 362.png | Format: PNG
# File: medicines 433.png | Format: PNG

# %%
def split_train_validation(dataset, validation_split=0.1):
    dataset_size = tf.data.experimental.cardinality(dataset).numpy()
    val_size = int(validation_split * dataset_size)

    val_ds = dataset.take(val_size)
    train_ds = dataset.skip(val_size)

    return train_ds, val_ds

# %%
train_ds, val_ds = split_train_validation(train_ds)

# %%
print(f"Train: {train_ds.cardinality().numpy()}, Validation: {val_ds.cardinality().numpy()}, Test: {test_ds.cardinality().numpy()}")
# Out:
# Train: 171, Validation: 18, Test: 57

# %%
from tensorflow.keras.layers import Rescaling, RandomFlip, RandomRotation, RandomZoom
from tensorflow.keras import Sequential

preprocessing_layer = Sequential([
    Rescaling(1./255),
    RandomFlip("horizontal"),
    RandomRotation(0.2),
    RandomZoom(0.2)
])

# %%
train_ds = train_ds.map(lambda x, y: (preprocessing_layer(x), y))
val_ds = val_ds.map(lambda x, y: (preprocessing_layer(x), y))
test_ds = test_ds.map(lambda x, y: (preprocessing_layer(x), y))

# %%
from tensorflow.keras.layers import Input, SeparableConv2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense, Dropout, Add
from tensorflow.keras.models import Model

def build_dp_cnn(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # === Parallel Convolutions ===
    conv1 = SeparableConv2D(128, (11, 11), padding="same")(inputs)
    conv2 = SeparableConv2D(128, (9, 9), padding="same")(inputs)
    conv3 = SeparableConv2D(128, (7, 7), padding="same")(inputs)
    conv4 = SeparableConv2D(128, (5, 5), padding="same")(inputs)
    conv5 = SeparableConv2D(128, (3, 3), padding="same")(inputs)

    # Batch Norm & Activation
    act1 = Activation("relu")(BatchNormalization()(conv1))
    act2 = Activation("relu")(BatchNormalization()(conv2))
    act3 = Activation("relu")(BatchNormalization()(conv3))
    act4 = Activation("relu")(BatchNormalization()(conv4))
    act5 = Activation("relu")(BatchNormalization()(conv5))

    # Merge parallel layers
    merged = Add()([act1, act2, act3, act4, act5])

    # === Depthwise Separable Convolutions ===
    conv6 = SeparableConv2D(128, (3, 3), activation="relu", padding="same")(merged)
    conv6 = BatchNormalization()(conv6)
    conv6 = MaxPooling2D(pool_size=(2, 2))(conv6)

    conv7 = SeparableConv2D(64, (3, 3), activation="relu", padding="same")(conv6)
    conv7 = BatchNormalization()(conv7)
    conv7 = MaxPooling2D(pool_size=(2, 2))(conv7)

    conv8 = SeparableConv2D(32, (3, 3), activation="relu", padding="same")(conv7)
    conv8 = BatchNormalization()(conv8)
    conv8 = MaxPooling2D(pool_size=(2, 2))(conv8)

    conv9 = SeparableConv2D(16, (3, 3), activation="relu", padding="same")(conv8)
    conv9 = BatchNormalization()(conv9)
    conv9 = MaxPooling2D(pool_size=(2, 2))(conv9)

    # === Fully Connected Layers ===
    flatten = Flatten()(conv9)
    dense1 = Dense(1024, activation="relu")(flatten)
    dense1 = Dropout(0.5)(dense1)

    dense2 = Dense(512, activation="relu")(dense1)
    dense2 = Dropout(0.5)(dense2)

    outputs = Dense(num_classes, activation="softmax")(dense2)

    model = Model(inputs, outputs)
    return model

# %%
# Build Model
model = build_dp_cnn((124, 124, 3), num_classes)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 124, 124, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d          │ (None, 124, 124, 128)  │            875 │ input_layer_1[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_1        │ (None, 124, 124, 128)  │            755 │ input_layer_1[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_2        │ (None, 124, 124, 128)  │            659 │ input_layer_1[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_3        │ (None, 124, 124, 128)  │            587 │ input_layer_1[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_4        │ (None, 124, 124, 128)  │            539 │ input_layer_1[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 124, 124, 128)  │            512 │ separable_conv2d[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 124, 124, 128)  │            512 │ separable_conv2d_1[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 124, 124, 128)  │            512 │ separable_conv2d_2[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 124, 124, 128)  │            512 │ separable_conv2d_3[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 124, 124, 128)  │            512 │ separable_conv2d_4[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 124, 124, 128)  │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 124, 124, 128)  │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 124, 124, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 124, 124, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 124, 124, 128)  │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 124, 124, 128)  │              0 │ activation[0][0],      │
# │                           │                        │                │ activation_1[0][0],    │
# │                           │                        │                │ activation_2[0][0],    │
# │                           │                        │                │ activation_3[0][0],    │
# │                           │                        │                │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_5        │ (None, 124, 124, 128)  │         17,664 │ add[0][0]              │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 124, 124, 128)  │            512 │ separable_conv2d_5[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 62, 62, 128)    │              0 │ batch_normalization_5… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_6        │ (None, 62, 62, 64)     │          9,408 │ max_pooling2d[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 62, 62, 64)     │            256 │ separable_conv2d_6[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 31, 31, 64)     │              0 │ batch_normalization_6… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_7        │ (None, 31, 31, 32)     │          2,656 │ max_pooling2d_1[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 31, 31, 32)     │            128 │ separable_conv2d_7[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 15, 15, 32)     │              0 │ batch_normalization_7… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_8        │ (None, 15, 15, 16)     │            816 │ max_pooling2d_2[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 15, 15, 16)     │             64 │ separable_conv2d_8[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 7, 7, 16)       │              0 │ batch_normalization_8… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 784)            │              0 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1024)           │        803,840 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 1024)           │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 512)            │        524,800 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 512)            │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 8)              │          4,104 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,370,223 (5.23 MB)
#  Trainable params: 1,368,463 (5.22 MB)
#  Non-trainable params: 1,760 (6.88 KB)

# %%
from tensorflow.keras.optimizers import Adam

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=150,
    batch_size=32
)
# Out:
# Epoch 1/150
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 90s 377ms/step - accuracy: 0.2490 - loss: 2.4053 - val_accuracy: 0.1059 - val_loss: 3.0029
# Epoch 2/150
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 53s 270ms/step - accuracy: 0.3815 - loss: 1.6792 - val_accuracy: 0.1597 - val_loss: 3.5701
# Epoch 3/150
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 55s 287ms/step - accuracy: 0.4264 - loss: 1.5497 - val_accuracy: 0.1788 - val_loss: 3.1358
# Epoch 4/150
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 55s 283ms/step - accuracy: 0.4390 - loss: 1.4532 - val_accuracy: 0.4358 - val_loss: 1.4793
# Epoch 5/150
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 57s 288ms/step - accuracy: 0.4597 - loss: 1.4369 - val_accuracy: 0.4705 - val_loss: 1.4590
# Epoch 6/150
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 52s 265ms/step - accuracy: 0.4758 - loss: 1.3700 - val_accuracy: 0.5469 - val_loss: 1.2327
# Epoch 7/150
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.5052 - loss: 1.3206 - val_accuracy: 0.4809 - val_loss: 1.4323
# Epoch 8/150
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 55s 280ms/step - accuracy: 0.5024 - loss: 1.3257 - val_accuracy: 0.4774 - val_loss: 1.3782
# Epoch 9/150
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 52s 268ms/step - accuracy: 0.5133 - loss: 1.2706 - val_accuracy: 0.4653 - val_loss: 1.5214
# Epoch 10/150
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 55s 287ms/step - accuracy: 0.5127 - loss: 1.2472 - val_accuracy: 0.4965 - val_loss: 1.3296
# Epoch 11/150
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 52s 269ms/step - accuracy: 0.5343 - loss: 1.2294 - val_accuracy: 0.4861 - val_loss: 1.4050
# Epoch 12/150
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 52s 272ms/step - accuracy: 0.5417 - loss: 1.2246 - val_accuracy: 0.4705 - val_loss: 1.3565
# Epoch 13/150
# 171/171 ━━━━━━━━━━━━━━━━━━━━